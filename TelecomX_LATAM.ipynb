# %% [markdown]
# <a href="https://colab.research.google.com/github/yaramirezte/TelecomX_LATAM/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/main/TelecomX_Data.json"

# %%
datos_TelecomX = pd.read_json(url)

# %%
datos_TelecomX.sample(10)
# Out:
#       customerID Churn                                           customer  \
# 4522  6198-ZFIOJ    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 5886  8046-DNVTL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 534   0754-EEBDC    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 644   0917-EZOLA   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 421   0607-DAAHE   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 814   1154-HYWWO    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 973   1370-AQYEM        {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 5206  7108-DGVUU    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 4342  5959-BELXA   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 6071  8292-FRFZQ    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                   phone  \
# 4522    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 5886  {'PhoneService': 'No', 'MultipleLines': 'No ph...
# 534      {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 644     {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 421      {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 814      {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 973      {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 5206    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 4342    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 6071  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 4522  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 5886  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 534   {'InternetService': 'No', 'OnlineSecurity': 'N...
# 644   {'InternetService': 'Fiber optic', 'OnlineSecu...
# 421   {'InternetService': 'No', 'OnlineSecurity': 'N...
# 814   {'InternetService': 'DSL', 'OnlineSecurity': '...
# 973   {'InternetService': 'Fiber optic', 'OnlineSecu...
# 5206  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 4342  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 6071  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account
# 4522  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 5886  {'Contract': 'Two year', 'PaperlessBilling': '...
# 534   {'Contract': 'Two year', 'PaperlessBilling': '...
# 644   {'Contract': 'Two year', 'PaperlessBilling': '...
# 421   {'Contract': 'Two year', 'PaperlessBilling': '...
# 814   {'Contract': 'One year', 'PaperlessBilling': '...
# 973   {'Contract': 'Month-to-month', 'PaperlessBilli...
# 5206  {'Contract': 'One year', 'PaperlessBilling': '...
# 4342  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 6071  {'Contract': 'One year', 'PaperlessBilling': '...

# %%
datos_TelecomX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
datos_TelecomX.dtypes
# Out:
# customerID    object
# Churn         object
# customer      object
# phone         object
# internet      object
# account       object
# dtype: object

# %%
datos_TelecomX.describe()
# Out:
#         customerID Churn                                           customer  \
# count         7267  7267                                               7267
# unique        7267     3                                                891
# top     9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# freq             1  5174                                                223
#
#                                                  phone  \
# count                                             7267
# unique                                               3
# top     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# freq                                              3495
#
#                                                  internet  \
# count                                                7267
# unique                                                129
# top     {'InternetService': 'No', 'OnlineSecurity': 'N...
# freq                                                 1581
#
#                                                   account
# count                                                7267
# unique                                               6931
# top     {'Contract': 'Month-to-month', 'PaperlessBilli...
# freq                                                    6

# %%
datos_TelecomX.isnull().sum()
# Out:
# customerID    0
# Churn         0
# customer      0
# phone         0
# internet      0
# account       0
# dtype: int64

# %%
datos_TelecomX.isna().sum()
# Out:
# customerID    0
# Churn         0
# customer      0
# phone         0
# internet      0
# account       0
# dtype: int64

# %%
datos_TelecomX.dtypes
# Out:
# customerID    object
# Churn         object
# customer      object
# phone         object
# internet      object
# account       object
# dtype: object

# %%
datos_TelecomX.map(type).head()
# Out:
#       customerID          Churn        customer           phone  \
# 0  <class 'str'>  <class 'str'>  <class 'dict'>  <class 'dict'>
# 1  <class 'str'>  <class 'str'>  <class 'dict'>  <class 'dict'>
# 2  <class 'str'>  <class 'str'>  <class 'dict'>  <class 'dict'>
# 3  <class 'str'>  <class 'str'>  <class 'dict'>  <class 'dict'>
# 4  <class 'str'>  <class 'str'>  <class 'dict'>  <class 'dict'>
#
#          internet         account
# 0  <class 'dict'>  <class 'dict'>
# 1  <class 'dict'>  <class 'dict'>
# 2  <class 'dict'>  <class 'dict'>
# 3  <class 'dict'>  <class 'dict'>
# 4  <class 'dict'>  <class 'dict'>

# %%
# pd.json_normalize() Recorre cada diccionario, entra dentro de los diccionarios anidados, saca cada clave interna, crea columnas nuevas usando notación con puntos
# datos_TelecomX.to_dict(orient="records") - Convierte el DataFrame en una lista de diccionarios, uno por fila.
datos_TelecomX_normalizados = pd.json_normalize(datos_TelecomX.to_dict(orient="records"))

# %%
datos_TelecomX_normalizados.duplicated().sum()
# Out:
# np.int64(0)

# %%
datos_TelecomX_normalizados['account.Contract'].unique()
# Out:
# array(['One year', 'Month-to-month', 'Two year'], dtype=object)

# %%
datos_TelecomX_normalizados['internet.InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
datos_TelecomX_normalizados['Churn'].unique()
# Out:
# array(['No', 'Yes', ''], dtype=object)

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# #📄Informe final
